# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Reading And Understanding the data**

# %%
# Importing necessory libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
churn = pd.read_csv('/content/drive/MyDrive/AlmaBetter/00_Team Capstone Projects/01_EDA/Telecom Churn Analysis/Telecom Churn.csv')
churn.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# check the dimensions of the data
churn.shape
# Out:
# (3333, 20)

# %%
# Information of the dataset
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# - There are no missing values present in the dataset.

# %%
# Statistical Summary of the dataset.
churn.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# - Here `Area Code` can be converted to Object datatype.

# %%
# Checking the value counts
churn['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
# Lets convert the datatype for the Area Code
churn['Area code'] = churn['Area code'].astype('object')

# %%
# Information of the dataset
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   object
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# # **Exploratory data Analysis**

# %%
# lets check the columns of dataset
churn.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Lets Seperate the categorical and numerical columns in a list
# Categorical columns
print('List of Categorical feature:')
cat_cols = churn.select_dtypes('object').columns
print(cat_cols)
print('='*80)
print('List of Numerical feature:')
# numerical columns list
num_cols = churn.select_dtypes(np.number).columns
print(num_cols)
# Out:
# List of Categorical feature
# Index(['State', 'Area code', 'International plan', 'Voice mail plan'], dtype='object')
# ...
# List of Numerical feature
# Index(['Account length', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls'],
#       dtype='object')

# %% [markdown]
# **Univariate Categorical Analysis**

# %%
# Check the value counts and pie chart
for cols in cat_cols:
  # Value counts
  print(churn[cols].value_counts())
  
  # Pie charts
  plt.figure(figsize=(12,5))
  churn[cols].value_counts().plot.pie(autopct = "%1.0f%%")
  plt.title("Pie Chart for {}".format(cols), fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Red'})
  plt.show()

  print("="*50,'\n')
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64
# ...
#
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64
# ...
#
# No     3010
# Yes     323
# Name: International plan, dtype: int64
# ...
#
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64
# ...

# %%
# Lets explore state column again 
print(churn['State'].nunique())
churn['State'].unique()
# Out:
# 51
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
# # Here lots of cities are given and have very less values in the city. So we will convert the all cities to other cities having less than 70 values.
# churn['State'] = churn['State'].apply(lambda x: x if x in list(churn['State'].value_counts().values > 80).index else 'Other_cities')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-0424bb29bd3f> in <module>()
#       1 # Here lots of cities are given and have very less values in the city. So we will convert the all cities to other cities having less than 70 values.
# ----> 2 churn['State'] = churn['State'].apply(lambda x: x if x in list(churn['State'].value_counts().values > 80).index else 'Other_cities')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
# ...

# %% [markdown]
# #####**Inferences**
# -

# %%
lst = list(churn['State'].value_counts().values > 80).index
lst
# Out:
# <function list.index>

# %%
# Lets explore state column again 
print(churn['State'].nunique())
churn['State'].unique()
# Out:
# 51
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %% [markdown]
# **Numerical Univariate Analysis**

# %%
# Lets draw box plot and histplot for all numerical columns
for cols in num_cols:
  # Box Plot 
  plt.figure(figsize=(16,8))
  plt.subplot(1,2,1)
  sns.boxplot(churn[cols])
  plt.title("Box plot for {}".format(cols), fontdict = {'fontsize': 12, 'fontweight' : 5, 'color' : 'Red'})

  # distplot 
  plt.subplot(1,2,2)
  sns.distplot(churn[cols])
  plt.title("Histogram for {}".format(cols), fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Red'})
  plt.show()
  plt.tight_layout()
