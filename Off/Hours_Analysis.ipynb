# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('FFT_Audi.xlsx')
df.head()
# Out:
#      Project  Area   AFO     Station      Units  CO-Ordination  3D Concept_P  \
# 0  Audi Gyor  SAAL  3110  15D 123456  BG01 Base              3             3
# 1  Audi Gyor  SAAL  3110  15D 123456   BG03 Pin              3             4
# 2  Audi Gyor  SAAL  3110  15D 123456   BG05 Pin              3             5
# 3  Audi Gyor  SAAL  3110  15D 123456   BG07 Pin              3             3
# 4  Audi Gyor  SAAL  3110  15D 123456   BG09 Pin              3             8
#
#    3D Finish_P  2D Hours_P  Delivery Data_P Supplier  3D Concept_G  \
# 0            5           3                2    Oasis           NaN
# 1            2           2                2    Oasis           NaN
# 2            2           3                2    Oasis           NaN
# 3            2           4                2    Oasis           NaN
# 4            3           3                2    Oasis           NaN
#
#    3D Finish_G  2D Hours_G  Delivery Data_G
# 0          NaN         NaN              NaN
# 1          NaN         NaN              NaN
# 2          NaN         NaN              NaN
# 3          NaN         NaN              NaN
# 4          NaN         NaN              NaN

# %%
# Randomnly add the hours for suppliers
def add_hrs(per,col1, col2):
    df[col1] = df[col2] * per

# %%
# Lets add hours for 3D Concept_G
add_hrs(2,'3D Concept_P',"3D Concept_G")

# %%
df.head()
# Out:
#      Project  Area   AFO     Station      Units  CO-Ordination  3D Concept_P  \
# 0  Audi Gyor  SAAL  3110  15D 123456  BG01 Base              3            12
# 1  Audi Gyor  SAAL  3110  15D 123456   BG03 Pin              3            16
# 2  Audi Gyor  SAAL  3110  15D 123456   BG05 Pin              3            20
# 3  Audi Gyor  SAAL  3110  15D 123456   BG07 Pin              3            12
# 4  Audi Gyor  SAAL  3110  15D 123456   BG09 Pin              3            32
#
#    3D Finish_P  2D Hours_P  Delivery Data_P Supplier  3D Concept_G  \
# 0            5           3                2    Oasis             6
# 1            2           2                2    Oasis             8
# 2            2           3                2    Oasis            10
# 3            2           4                2    Oasis             6
# 4            3           3                2    Oasis            16
#
#    3D Finish_G  2D Hours_G  Delivery Data_G
# 0          NaN         NaN              NaN
# 1          NaN         NaN              NaN
# 2          NaN         NaN              NaN
# 3          NaN         NaN              NaN
# 4          NaN         NaN              NaN
